# %% [markdown]
# pandas(Created by Wes McKinney in 2008)
#     pandas contain high-level datastructures and manipulation tools designed to make data analysis fast and easy.
#     pandas are built on top of numpy which makes it easy to use in numpy centric applications.

# %%
import pandas as pd
import numpy as np

# %%
labels = ['a', 'b', 'c']
my_data = [1, 2, 3]
arr = np.array(my_data)

# %% [markdown]
# Syantax for creating a series
# pd.Series(data, index)

# %%
my_series = pd.Series(my_data, labels) # Creating a series

# %%
my_series['c']
# Out:
# 3

# %%
my_series+my_series
# Out:
# a    2
# b    4
# c    6
# dtype: int64

# %%
from numpy.random import randn

# %%
np.random.seed(10)

# %%
df = pd.DataFrame(data=randn(5, 4), index=['A', 'B', 'C', 'D', 'E'], columns=['W', 'X', 'Y', 'Z'])

# %%
type(df['X'])
# Out:
# pandas.core.series.Series

# %%
df[['W', 'X']] # Slicing a dataframe
# Out:
#           W         X
# A  1.331587  0.715279
# B  0.621336 -0.720086
# C  0.004291 -0.174600
# D -0.965066  1.028274
# E -1.136602  0.135137

# %%
df['new'] = df['W'] + df['X']

# %%
df.drop('new', axis=1, inplace=True)

# %%
df.drop('E', axis=0, inplace=True)

# %%
df
# Out:
#           W         X         Y         Z
# A  1.331587  0.715279 -1.545400 -0.008384
# B  0.621336 -0.720086  0.265512  0.108549
# C  0.004291 -0.174600  0.433026  1.203037
# D -0.965066  1.028274  0.228630  0.445138

# %%
df.shape # Returns a tuple consisting of rows, columns
# Out:
# (4, 4)

# %%
df.loc['A']
# Out:
# W    1.331587
# X    0.715279
# Y   -1.545400
# Z   -0.008384
# Name: A, dtype: float64

# %%
df.iloc[1]
# Out:
# W    0.621336
# X   -0.720086
# Y    0.265512
# Z    0.108549
# Name: B, dtype: float64

# %%
df.loc[['A', 'B'], ['Y', 'W']]
# Out:
#           Y         W
# A -1.545400  1.331587
# B  0.265512  0.621336

# %%
df.axes
# Out:
# [Index(['A', 'B', 'C', 'D'], dtype='object'),
#  Index(['W', 'X', 'Y', 'Z'], dtype='object')]

# %%
booldf = df > 0 # Conditional selection returns boolean values.

# %%
df[df['Z'] > 0][['X', 'W']]
# Out:
#           X         W
# B -0.720086  0.621336
# C -0.174600  0.004291
# D  1.028274 -0.965066

# %%
# set vs reset index

# %%
#multi index and index hierarchy

# %%
# Missing values
d = {'A':[1, 2], 'B':[5, np.nan]}
df = pd.DataFrame(d)

# %%
df # Threshold value (min no of nan for the row or col to be dropped.)
# Out:
#    A    B
# 0  1  5.0
# 1  2  NaN

# %%
# the fillna(value=) method, v Important

# %%
df.fillna(value=df['A'].mean())
# Out:
#    A    B
# 0  1  5.0
# 1  2  1.5
